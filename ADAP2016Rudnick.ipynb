# %% [markdown]
# Greg wants SFR vs Mass without color coding for size

# %%
import numpy as np
from pylab import *
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# %run ~/Dropbox/pythonCode/LCSanalyzeblue.py
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%
#
#  prefix =
# all
# %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%
# %%%%%%%%%%%%%%%%%%%%%%%%%%
# PREFIX =
#  all

# %%
s.plotSFRStellarmassSizeBlue(blueflag=True,plotbadfits=False)

# %%
s.plotSFRStellarmassSizeBlue(blueflag=True,plotbadfits=False,nocolor=True)
