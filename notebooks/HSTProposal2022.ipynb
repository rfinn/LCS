# %%
import numpy as np
from matplotlib import pyplot as plt
import os
import sys
import warnings
warnings.filterwarnings('ignore')

import time

from scipy.stats import ks_2samp

from astropy.io import fits,ascii
from astropy.table import Table
from astropy.coordinates import SkyCoord
from astropy import units as u
homedir = os.getenv("HOME")

# %%
# %%time
os.chdir(homedir+'/research/LCS/plots/')
# %run ~/github/LCS/python/lcs_paper2_v2.py --ellip 0.75 --minmass 9.7 --minssfr -11.5 --cutBT --BT 0.3
mmatch=True

if mmatch:
    flag = (b.lcs.membflag | b.lcs.infallflag) 
    outfile1 = homedir+'/research/LCS/plots/lcscore-gsw-sfrmstar-BTcut03-e0p75-mmatch-HST.pdf'
    outfile2 = homedir+'/research/LCS/plots/lcscore-gsw-sfrmstar-BTcut03-e0p75-mmatch-HST.png'
    b.plot_sfr_mstar(lcsflag=flag,coreflag=True,plotMS=True,plotlegend=False,outfile1=outfile1,outfile2=outfile2,massmatch=True,hexbinflag=False,marker2='s')
# Out:
# outfile =  /Users/rfinn/research/GSWLC/GSWLC-X2-NO-DR10-AGN-Simard2011-tab1-tab3-Tempel-13-2021Jan07-LCS-Zoverlap-BTcut.fits
# number of lines in LCS cat =  2955
# inside LCS cut_BT, BT =  0.3
# inside LCS cut_BT, BTkey =  __B_T_r
# got sb flag
# 1305 1305 1305 1305
# number in lcs sample =  302
# number in gsw sample =  7590
# just checking ... 9060 302
# 9.701
# 9.702
# ############################################################
# KS test comparising galaxies within range shown on the plot
#
# STELLAR MASS
# KS Test:
# D =   0.03
# p-vale = 9.526e-01 (prob that samples are from same distribution)
# Anderson-Darling:  Anderson_ksampResult(statistic=-0.7762873325585654, critical_values=array([0.325, 1.226, 1.961, 2.718, 3.752, 4.592, 6.546]), significance_level=0.25)
#
# COLOR
# KS Test:
# D =   0.15
# p-vale = 2.751e-06 (prob that samples are from same distribution)
# Anderson-Darling:  Anderson_ksampResult(statistic=19.44172245838336, critical_values=array([0.325, 1.226, 1.961, 2.718, 3.752, 4.592, 6.546]), significance_level=0.001)
# CPU times: user 12.3 s, sys: 400 ms, total: 12.7 s
# Wall time: 13.8 s
